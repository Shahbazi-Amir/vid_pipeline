# %% [markdown]
# # Financial Video RAG Pipeline — Google Colab
# این Notebook پایپ‌لاین را روی Colab نصب می‌کند. برای جلوگیری از شروع دوباره، مسیر `work` را روی Google Drive نگه دارید.

# %%
# !apt-get update -qq
# !apt-get install -y -qq ffmpeg
# !git clone https://github.com/Shahbazi-Amir/vid_pipeline.git
# %cd vid_pipeline
# !pip install -q -e '.[all]'
# !vid-pipeline --version

# %%
from google.colab import drive
drive.mount('/content/drive')
WORK_ROOT = '/content/drive/MyDrive/financial-rag-work'
SPEC = '/content/vid_pipeline/examples/asre-shirin-season-2-episode-01.json'
print(WORK_ROOT)

# %% [markdown]
# قبل از اجرا، فایل مشخصات قسمت را با URL قطعی منبع و ویدئو ویرایش کنید. حضور دکتر کمیل رودی و شماره قسمت باید بررسی شده باشد.

# %%
# !vid-pipeline run "$SPEC" --work-root "$WORK_ROOT" --model small --device auto

# %%
# !vid-pipeline status "$SPEC" --work-root "$WORK_ROOT"
